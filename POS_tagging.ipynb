# %% [markdown]
# # A Quantum-Enhanced LSTM Layer

# %% [markdown]
# One field that so far has been poorly explored in Quantum Machine Learning is Natural Language Processing (NLP), the sub-field of Artificial Intelligence that gives computers the ability to read, write and to some extent comprehend written text.
#
# As documents are usually presented as sequences of words, historically one of the most successful techniques to manipulate this kind of data has been the Recurrent Neural Network architecture, and in particular a variant called Long Short-Term Memory (LSTM). LSTMs allowed machines to perform translations, classification and intent detection with state-of-the-art accuracy until the advent of Transformer networks. Still, it’s interesting at least from an educational point of view to dig into LSTMs to see what good quantum computing may bring to the field. For a more thorough discussion, please refer to “Quantum Long Short-Term Memory” by Chen, Yoo and Fang (arXiv:2009.01783) and “Recurrent Quantum Neural Networks” by J. Bausch (arXiv:2006.14619).

# %%
# !pip install -r requirements.txt
# Out:
# Collecting absl-py==0.12.0 (from -r requirements.txt (line 1))
#   Downloading absl_py-0.12.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting aiohttp==3.7.4.post0 (from -r requirements.txt (line 2))
#   Downloading aiohttp-3.7.4.post0.tar.gz (1.1 MB)
#      ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#      --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#      ------------------------------------- -- 1.0/1.1 MB 3.1 MB/s eta 0:00:01
#      ---------------------------------------- 1.1/1.1 MB 3.0 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: appdirs==1.4.4 in c:\users\muham\appdata\local\programs\python\python312\lib\site-packages (from -r requirements.txt (line 3)) (1.4.4)
# Collecting appnope==0.1.2 (from -r requirements.txt (line 4))
#   Downloading appnope-0.1.2-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting argon2-cffi==21.1.0 (from -r requirements.txt (line 5))
#   Downloading argon2_cffi-21.1.0-cp35-abi3-win_amd64.whl.metadata (7.1 kB)
# Collecting async-timeout==3.0.1 (from -r requirements.txt (line 6))
#   Downloading async_timeout-3.0.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting attrs==20.3.0 (from -r requirements.txt (line 7))
#   Downloading attrs-20.3.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting autograd==1.3 (from -r requirements.txt (line 8))
#   Downloading autograd-1.3.tar.gz (38 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting backcall==0.2.0 (from -r requirements.txt (line 9))
#   Downloading backcall-0.2.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting beautifulsoup4==4.9.3 (from -r requirements.txt (line 10))
#   Downloading beautifulsoup4-4.9.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting bleach==4.1.0 (from -r requirements.txt (line 11))
#   Downloading bleach-4.1.0-py2.py3-none-any.whl.metadata (24 kB)
# Collecting bs4==0.0.1 (from -r requirements.txt (line 12))
#   Downloading bs4-0.0.1.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cachetools==4.2.1 (from -r requirements.txt (line 13))
#   Downloading cachetools-4.2.1-py3-none-any.whl.metadata (4.6 kB)
# Collecting certifi==2020.12.5 (from -r requirements.txt (line 14))
#   Downloading certifi-2020.12.5-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting cffi==1.14.5 (from -r requirements.txt (line 15))
#   Downloading cffi-1.14.5.tar.gz (475 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# WARNING: Ignoring invalid distribution ~treamlit (C:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~yspark (C:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [24 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\muham\AppData\Local\Temp\pip-install-eha5k2wa\cffi_5f6b1467771743e491acd5f2dd9b6f55\setup.py", line 127, in <module>
#           if sys.platform == 'win32' and uses_msvc():
#                                          ^^^^^^^^^^^
#         File "C:\Users\muham\AppData\Local\Temp\pip-install-eha5k2wa\cffi_5f6b1467771743e491acd5f2dd9b6f55\setup.py", line 105, in uses_msvc
#           return config.try_compile('#ifndef _MSC_VER\n#error "not MSVC"\n#endif')
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\setuptools\_distutils\command\config.py", line 220, in try_compile
#           self._compile(body, headers, include_dirs, lang)
#         File "C:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\setuptools\_distutils\command\config.py", line 132, in _compile
#           self.compiler.compile([src], include_dirs=include_dirs)
#         File "C:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 343, in compile
#           self.initialize()
#         File "C:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\setuptools\_distutils\_msvccompiler.py", line 253, in initialize
#           vc_env = _get_vc_env(plat_spec)
#                    ^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\setuptools\msvc.py", line 230, in msvc14_get_vc_env
#           return _msvc14_get_vc_env(plat_spec)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "C:\Users\muham\AppData\Local\Programs\Python\Python312\Lib\site-packages\setuptools\msvc.py", line 187, in _msvc14_get_vc_env
#           raise distutils.errors.DistutilsPlatformError("Unable to find vcvarsall.bat")
#       distutils.errors.DistutilsPlatformError: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

from qlstm_pennylane import QLSTM

# %% [markdown]
# Here we define the possible tags: determinant, noun, verb.

# %%
tag_to_ix = {"DET": 0, "NN": 1, "V": 2}  # Assign each tag with a unique index
ix_to_tag = {i:k for k,i in tag_to_ix.items()}

# %% [markdown]
# The function below tokenizes the sentence and matches the label to each word.

# %%
def prepare_sequence(seq, to_ix):
    idxs = [to_ix[w] for w in seq]
    return torch.tensor(idxs, dtype=torch.long)

# %% [markdown]
# Now we can prepare the input dataset.

# %%
training_data = [
    # Tags are: DET - determiner; NN - noun; V - verb
    # For example, the word "The" is a determiner
    ("The dog ate the apple".split(), ["DET", "NN", "V", "DET", "NN"]),
    ("Everybody read that book".split(), ["NN", "V", "DET", "NN"])
]
word_to_ix = {}

# For each words-list (sentence) and tags-list in each tuple of training_data
for sent, tags in training_data:
    for word in sent:
        if word not in word_to_ix:  # word has not been assigned an index yet
            word_to_ix[word] = len(word_to_ix)  # Assign each word with a unique index

print(f"Vocabulary: {word_to_ix}")
print(f"Entities: {ix_to_tag}")
# Out:
# Vocabulary: {'The': 0, 'dog': 1, 'ate': 2, 'the': 3, 'apple': 4, 'Everybody': 5, 'read': 6, 'that': 7, 'book': 8}
# Entities: {0: 'DET', 1: 'NN', 2: 'V'}

# %% [markdown]
# The idea is to pass the two sequences through the LSTM, which will output the hidden array of vectors [h_0, h_1, h_2, h_3, h_4], one for each word. A dense layer “head” is attached to the LSTM’s outputs to calculate the probability that each word may be a determinant, noun or verb.

# %%
class LSTMTagger(nn.Module):

    def __init__(self, embedding_dim, hidden_dim, vocab_size, tagset_size, n_qubits=0):
        super(LSTMTagger, self).__init__()
        self.hidden_dim = hidden_dim

        self.word_embeddings = nn.Embedding(vocab_size, embedding_dim)

        # The LSTM takes word embeddings as inputs, and outputs hidden states
        # with dimensionality hidden_dim.
        if n_qubits > 0:
            print("Tagger will use Quantum LSTM")
            self.lstm = QLSTM(embedding_dim, hidden_dim, n_qubits=n_qubits)
        else:
            print("Tagger will use Classical LSTM")
            self.lstm = nn.LSTM(embedding_dim, hidden_dim)

        # The linear layer that maps from hidden state space to tag space
        self.hidden2tag = nn.Linear(hidden_dim, tagset_size)

    def forward(self, sentence):
        embeds = self.word_embeddings(sentence)
        lstm_out, _ = self.lstm(embeds.view(len(sentence), 1, -1))
        tag_logits = self.hidden2tag(lstm_out.view(len(sentence), -1))
        tag_scores = F.log_softmax(tag_logits, dim=1)
        return tag_scores

# %%
embedding_dim = 8
hidden_dim = 6
n_epochs = 300

# %%
model_classical = LSTMTagger(embedding_dim, 
                        hidden_dim, 
                        vocab_size=len(word_to_ix), 
                        tagset_size=len(tag_to_ix), 
                        n_qubits=0)
# Out:
# Tagger will use Classical LSTM

# %% [markdown]
# ## Training

# %% [markdown]
# Following the example from the PyTorch website, we train the two networks (classical and quantum LSTM) for 300 epochs.

# %%
def train(model, n_epochs):
    loss_function = nn.NLLLoss()
    optimizer = optim.SGD(model.parameters(), lr=0.1)

    history = {
        'loss': [],
        'acc': []
    }
    for epoch in range(n_epochs):
        losses = []
        preds = []
        targets = []
        for sentence, tags in training_data:
            # Step 1. Remember that Pytorch accumulates gradients.
            # We need to clear them out before each instance
            model.zero_grad()

            # Step 2. Get our inputs ready for the network, that is, turn them into
            # Tensors of word indices.
            sentence_in = prepare_sequence(sentence, word_to_ix)
            labels = prepare_sequence(tags, tag_to_ix)

            # Step 3. Run our forward pass.
            tag_scores = model(sentence_in)

            # Step 4. Compute the loss, gradients, and update the parameters by
            #  calling optimizer.step()
            loss = loss_function(tag_scores, labels)
            loss.backward()
            optimizer.step()
            losses.append(float(loss))
            
            probs = torch.softmax(tag_scores, dim=-1)
            preds.append(probs.argmax(dim=-1))
            targets.append(labels)

        avg_loss = np.mean(losses)
        history['loss'].append(avg_loss)
        
        preds = torch.cat(preds)
        targets = torch.cat(targets)
        corrects = (preds == targets)
        accuracy = corrects.sum().float() / float(targets.size(0) )
        history['acc'].append(accuracy)

        print(f"Epoch {epoch+1} / {n_epochs}: Loss = {avg_loss:.3f} Acc = {accuracy:.2f}")

    return history

# %%
history_classical = train(model_classical, n_epochs)
# Out:
# Epoch 1 / 300: Loss = 1.117 Acc = 0.22
# Epoch 2 / 300: Loss = 1.108 Acc = 0.22
# Epoch 3 / 300: Loss = 1.099 Acc = 0.33
# Epoch 4 / 300: Loss = 1.091 Acc = 0.33
# Epoch 5 / 300: Loss = 1.084 Acc = 0.33
# Epoch 6 / 300: Loss = 1.077 Acc = 0.44
# Epoch 7 / 300: Loss = 1.070 Acc = 0.56
# Epoch 8 / 300: Loss = 1.065 Acc = 0.56
# Epoch 9 / 300: Loss = 1.059 Acc = 0.56
# Epoch 10 / 300: Loss = 1.054 Acc = 0.56
# Epoch 11 / 300: Loss = 1.050 Acc = 0.56
# Epoch 12 / 300: Loss = 1.046 Acc = 0.56
# Epoch 13 / 300: Loss = 1.042 Acc = 0.56
# Epoch 14 / 300: Loss = 1.038 Acc = 0.56
# Epoch 15 / 300: Loss = 1.034 Acc = 0.56
# Epoch 16 / 300: Loss = 1.031 Acc = 0.56
# Epoch 17 / 300: Loss = 1.027 Acc = 0.56
# Epoch 18 / 300: Loss = 1.023 Acc = 0.56
# Epoch 19 / 300: Loss = 1.020 Acc = 0.56
# Epoch 20 / 300: Loss = 1.016 Acc = 0.56
# Epoch 21 / 300: Loss = 1.013 Acc = 0.56
# Epoch 22 / 300: Loss = 1.009 Acc = 0.56
# Epoch 23 / 300: Loss = 1.005 Acc = 0.56
# Epoch 24 / 300: Loss = 1.002 Acc = 0.56
# Epoch 25 / 300: Loss = 0.998 Acc = 0.56
# Epoch 26 / 300: Loss = 0.994 Acc = 0.56
# Epoch 27 / 300: Loss = 0.990 Acc = 0.56
# Epoch 28 / 300: Loss = 0.986 Acc = 0.56
# Epoch 29 / 300: Loss = 0.982 Acc = 0.56
# Epoch 30 / 300: Loss = 0.977 Acc = 0.56
# Epoch 31 / 300: Loss = 0.973 Acc = 0.56
# Epoch 32 / 300: Loss = 0.968 Acc = 0.56
# Epoch 33 / 300: Loss = 0.964 Acc = 0.56
# Epoch 34 / 300: Loss = 0.959 Acc = 0.56
# Epoch 35 / 300: Loss = 0.954 Acc = 0.56
# Epoch 36 / 300: Loss = 0.949 Acc = 0.56
# Epoch 37 / 300: Loss = 0.944 Acc = 0.56
# Epoch 38 / 300: Loss = 0.939 Acc = 0.56
# Epoch 39 / 300: Loss = 0.934 Acc = 0.56
# Epoch 40 / 300: Loss = 0.929 Acc = 0.56
# Epoch 41 / 300: Loss = 0.923 Acc = 0.56
# Epoch 42 / 300: Loss = 0.918 Acc = 0.56
# Epoch 43 / 300: Loss = 0.912 Acc = 0.56
# Epoch 44 / 300: Loss = 0.906 Acc = 0.56
# Epoch 45 / 300: Loss = 0.901 Acc = 0.56
# Epoch 46 / 300: Loss = 0.895 Acc = 0.56
# Epoch 47 / 300: Loss = 0.889 Acc = 0.56
# Epoch 48 / 300: Loss = 0.883 Acc = 0.56
# Epoch 49 / 300: Loss = 0.877 Acc = 0.56
# Epoch 50 / 300: Loss = 0.871 Acc = 0.56
# Epoch 51 / 300: Loss = 0.865 Acc = 0.56
# Epoch 52 / 300: Loss = 0.859 Acc = 0.56
# Epoch 53 / 300: Loss = 0.853 Acc = 0.56
# Epoch 54 / 300: Loss = 0.846 Acc = 0.56
# Epoch 55 / 300: Loss = 0.840 Acc = 0.56
# Epoch 56 / 300: Loss = 0.834 Acc = 0.56
# Epoch 57 / 300: Loss = 0.827 Acc = 0.67
# Epoch 58 / 300: Loss = 0.821 Acc = 0.67
# Epoch 59 / 300: Loss = 0.814 Acc = 0.67
# Epoch 60 / 300: Loss = 0.808 Acc = 0.67
# Epoch 61 / 300: Loss = 0.801 Acc = 0.67
# Epoch 62 / 300: Loss = 0.795 Acc = 0.67
# Epoch 63 / 300: Loss = 0.788 Acc = 0.67
# Epoch 64 / 300: Loss = 0.781 Acc = 0.67
# Epoch 65 / 300: Loss = 0.775 Acc = 0.78
# Epoch 66 / 300: Loss = 0.768 Acc = 0.78
# Epoch 67 / 300: Loss = 0.761 Acc = 0.78
# Epoch 68 / 300: Loss = 0.754 Acc = 0.78
# Epoch 69 / 300: Loss = 0.748 Acc = 0.78
# Epoch 70 / 300: Loss = 0.741 Acc = 0.78
# Epoch 71 / 300: Loss = 0.734 Acc = 0.78
# Epoch 72 / 300: Loss = 0.727 Acc = 0.78
# Epoch 73 / 300: Loss = 0.720 Acc = 0.78
# Epoch 74 / 300: Loss = 0.713 Acc = 0.78
# Epoch 75 / 300: Loss = 0.706 Acc = 0.78
# Epoch 76 / 300: Loss = 0.699 Acc = 0.78
# Epoch 77 / 300: Loss = 0.692 Acc = 0.78
# Epoch 78 / 300: Loss = 0.685 Acc = 0.78
# Epoch 79 / 300: Loss = 0.678 Acc = 0.78
# Epoch 80 / 300: Loss = 0.670 Acc = 0.78
# Epoch 81 / 300: Loss = 0.663 Acc = 0.78
# Epoch 82 / 300: Loss = 0.656 Acc = 0.78
# Epoch 83 / 300: Loss = 0.649 Acc = 0.78
# Epoch 84 / 300: Loss = 0.641 Acc = 0.78
# Epoch 85 / 300: Loss = 0.634 Acc = 0.78
# Epoch 86 / 300: Loss = 0.627 Acc = 0.78
# Epoch 87 / 300: Loss = 0.619 Acc = 0.78
# Epoch 88 / 300: Loss = 0.612 Acc = 0.78
# Epoch 89 / 300: Loss = 0.605 Acc = 0.78
# Epoch 90 / 300: Loss = 0.597 Acc = 0.78
# Epoch 91 / 300: Loss = 0.590 Acc = 0.78
# Epoch 92 / 300: Loss = 0.583 Acc = 0.78
# Epoch 93 / 300: Loss = 0.575 Acc = 0.78
# Epoch 94 / 300: Loss = 0.568 Acc = 0.78
# Epoch 95 / 300: Loss = 0.560 Acc = 0.78
# Epoch 96 / 300: Loss = 0.553 Acc = 0.78
# Epoch 97 / 300: Loss = 0.546 Acc = 0.78
# Epoch 98 / 300: Loss = 0.538 Acc = 0.78
# Epoch 99 / 300: Loss = 0.531 Acc = 0.89
# Epoch 100 / 300: Loss = 0.524 Acc = 0.89
# Epoch 101 / 300: Loss = 0.517 Acc = 0.89
# Epoch 102 / 300: Loss = 0.509 Acc = 0.89
# Epoch 103 / 300: Loss = 0.502 Acc = 0.89
# Epoch 104 / 300: Loss = 0.495 Acc = 0.89
# Epoch 105 / 300: Loss = 0.488 Acc = 0.89
# Epoch 106 / 300: Loss = 0.481 Acc = 0.89
# Epoch 107 / 300: Loss = 0.475 Acc = 0.89
# Epoch 108 / 300: Loss = 0.468 Acc = 0.89
# Epoch 109 / 300: Loss = 0.461 Acc = 0.89
# Epoch 110 / 300: Loss = 0.455 Acc = 0.89
# Epoch 111 / 300: Loss = 0.448 Acc = 0.89
# Epoch 112 / 300: Loss = 0.442 Acc = 0.89
# Epoch 113 / 300: Loss = 0.435 Acc = 0.89
# Epoch 114 / 300: Loss = 0.429 Acc = 0.89
# Epoch 115 / 300: Loss = 0.423 Acc = 0.89
# Epoch 116 / 300: Loss = 0.417 Acc = 0.89
# Epoch 117 / 300: Loss = 0.411 Acc = 0.89
# Epoch 118 / 300: Loss = 0.405 Acc = 0.89
# Epoch 119 / 300: Loss = 0.400 Acc = 0.89
# Epoch 120 / 300: Loss = 0.394 Acc = 0.89
# Epoch 121 / 300: Loss = 0.388 Acc = 0.89
# Epoch 122 / 300: Loss = 0.383 Acc = 0.89
# Epoch 123 / 300: Loss = 0.378 Acc = 0.89
# Epoch 124 / 300: Loss = 0.372 Acc = 0.89
# Epoch 125 / 300: Loss = 0.367 Acc = 0.89
# Epoch 126 / 300: Loss = 0.362 Acc = 0.89
# Epoch 127 / 300: Loss = 0.357 Acc = 0.89
# Epoch 128 / 300: Loss = 0.352 Acc = 0.89
# Epoch 129 / 300: Loss = 0.348 Acc = 0.89
# Epoch 130 / 300: Loss = 0.343 Acc = 0.89
# Epoch 131 / 300: Loss = 0.338 Acc = 0.89
# Epoch 132 / 300: Loss = 0.334 Acc = 0.89
# Epoch 133 / 300: Loss = 0.329 Acc = 0.89
# Epoch 134 / 300: Loss = 0.325 Acc = 0.89
# Epoch 135 / 300: Loss = 0.320 Acc = 0.89
# Epoch 136 / 300: Loss = 0.316 Acc = 0.89
# Epoch 137 / 300: Loss = 0.312 Acc = 0.89
# Epoch 138 / 300: Loss = 0.308 Acc = 0.89
# Epoch 139 / 300: Loss = 0.304 Acc = 0.89
# Epoch 140 / 300: Loss = 0.300 Acc = 0.89
# Epoch 141 / 300: Loss = 0.296 Acc = 0.89
# Epoch 142 / 300: Loss = 0.292 Acc = 0.89
# Epoch 143 / 300: Loss = 0.289 Acc = 0.89
# Epoch 144 / 300: Loss = 0.285 Acc = 0.89
# Epoch 145 / 300: Loss = 0.281 Acc = 0.89
# Epoch 146 / 300: Loss = 0.278 Acc = 1.00
# Epoch 147 / 300: Loss = 0.274 Acc = 1.00
# Epoch 148 / 300: Loss = 0.271 Acc = 1.00
# Epoch 149 / 300: Loss = 0.267 Acc = 1.00
# Epoch 150 / 300: Loss = 0.264 Acc = 1.00
# Epoch 151 / 300: Loss = 0.261 Acc = 1.00
# Epoch 152 / 300: Loss = 0.257 Acc = 1.00
# Epoch 153 / 300: Loss = 0.254 Acc = 1.00
# Epoch 154 / 300: Loss = 0.251 Acc = 1.00
# Epoch 155 / 300: Loss = 0.248 Acc = 1.00
# Epoch 156 / 300: Loss = 0.245 Acc = 1.00
# Epoch 157 / 300: Loss = 0.242 Acc = 1.00
# Epoch 158 / 300: Loss = 0.239 Acc = 1.00
# Epoch 159 / 300: Loss = 0.236 Acc = 1.00
# Epoch 160 / 300: Loss = 0.233 Acc = 1.00
# Epoch 161 / 300: Loss = 0.230 Acc = 1.00
# Epoch 162 / 300: Loss = 0.227 Acc = 1.00
# Epoch 163 / 300: Loss = 0.225 Acc = 1.00
# Epoch 164 / 300: Loss = 0.222 Acc = 1.00
# Epoch 165 / 300: Loss = 0.219 Acc = 1.00
# Epoch 166 / 300: Loss = 0.217 Acc = 1.00
# Epoch 167 / 300: Loss = 0.214 Acc = 1.00
# Epoch 168 / 300: Loss = 0.212 Acc = 1.00
# Epoch 169 / 300: Loss = 0.209 Acc = 1.00
# Epoch 170 / 300: Loss = 0.206 Acc = 1.00
# Epoch 171 / 300: Loss = 0.204 Acc = 1.00
# Epoch 172 / 300: Loss = 0.202 Acc = 1.00
# Epoch 173 / 300: Loss = 0.199 Acc = 1.00
# Epoch 174 / 300: Loss = 0.197 Acc = 1.00
# Epoch 175 / 300: Loss = 0.194 Acc = 1.00
# Epoch 176 / 300: Loss = 0.192 Acc = 1.00
# Epoch 177 / 300: Loss = 0.190 Acc = 1.00
# Epoch 178 / 300: Loss = 0.188 Acc = 1.00
# Epoch 179 / 300: Loss = 0.185 Acc = 1.00
# Epoch 180 / 300: Loss = 0.183 Acc = 1.00
# Epoch 181 / 300: Loss = 0.181 Acc = 1.00
# Epoch 182 / 300: Loss = 0.179 Acc = 1.00
# Epoch 183 / 300: Loss = 0.177 Acc = 1.00
# Epoch 184 / 300: Loss = 0.175 Acc = 1.00
# Epoch 185 / 300: Loss = 0.172 Acc = 1.00
# Epoch 186 / 300: Loss = 0.170 Acc = 1.00
# Epoch 187 / 300: Loss = 0.168 Acc = 1.00
# Epoch 188 / 300: Loss = 0.166 Acc = 1.00
# Epoch 189 / 300: Loss = 0.164 Acc = 1.00
# Epoch 190 / 300: Loss = 0.162 Acc = 1.00
# Epoch 191 / 300: Loss = 0.161 Acc = 1.00
# Epoch 192 / 300: Loss = 0.159 Acc = 1.00
# Epoch 193 / 300: Loss = 0.157 Acc = 1.00
# Epoch 194 / 300: Loss = 0.155 Acc = 1.00
# Epoch 195 / 300: Loss = 0.153 Acc = 1.00
# Epoch 196 / 300: Loss = 0.151 Acc = 1.00
# Epoch 197 / 300: Loss = 0.149 Acc = 1.00
# Epoch 198 / 300: Loss = 0.148 Acc = 1.00
# Epoch 199 / 300: Loss = 0.146 Acc = 1.00
# Epoch 200 / 300: Loss = 0.144 Acc = 1.00
# Epoch 201 / 300: Loss = 0.142 Acc = 1.00
# Epoch 202 / 300: Loss = 0.141 Acc = 1.00
# Epoch 203 / 300: Loss = 0.139 Acc = 1.00
# Epoch 204 / 300: Loss = 0.137 Acc = 1.00
# Epoch 205 / 300: Loss = 0.136 Acc = 1.00
# Epoch 206 / 300: Loss = 0.134 Acc = 1.00
# Epoch 207 / 300: Loss = 0.133 Acc = 1.00
# Epoch 208 / 300: Loss = 0.131 Acc = 1.00
# Epoch 209 / 300: Loss = 0.130 Acc = 1.00
# Epoch 210 / 300: Loss = 0.128 Acc = 1.00
# Epoch 211 / 300: Loss = 0.127 Acc = 1.00
# Epoch 212 / 300: Loss = 0.125 Acc = 1.00
# Epoch 213 / 300: Loss = 0.124 Acc = 1.00
# Epoch 214 / 300: Loss = 0.122 Acc = 1.00
# Epoch 215 / 300: Loss = 0.121 Acc = 1.00
# Epoch 216 / 300: Loss = 0.119 Acc = 1.00
# Epoch 217 / 300: Loss = 0.118 Acc = 1.00
# Epoch 218 / 300: Loss = 0.116 Acc = 1.00
# Epoch 219 / 300: Loss = 0.115 Acc = 1.00
# Epoch 220 / 300: Loss = 0.114 Acc = 1.00
# Epoch 221 / 300: Loss = 0.112 Acc = 1.00
# Epoch 222 / 300: Loss = 0.111 Acc = 1.00
# Epoch 223 / 300: Loss = 0.110 Acc = 1.00
# Epoch 224 / 300: Loss = 0.109 Acc = 1.00
# Epoch 225 / 300: Loss = 0.107 Acc = 1.00
# Epoch 226 / 300: Loss = 0.106 Acc = 1.00
# Epoch 227 / 300: Loss = 0.105 Acc = 1.00
# Epoch 228 / 300: Loss = 0.104 Acc = 1.00
# Epoch 229 / 300: Loss = 0.103 Acc = 1.00
# Epoch 230 / 300: Loss = 0.101 Acc = 1.00
# Epoch 231 / 300: Loss = 0.100 Acc = 1.00
# Epoch 232 / 300: Loss = 0.099 Acc = 1.00
# Epoch 233 / 300: Loss = 0.098 Acc = 1.00
# Epoch 234 / 300: Loss = 0.097 Acc = 1.00
# Epoch 235 / 300: Loss = 0.096 Acc = 1.00
# Epoch 236 / 300: Loss = 0.095 Acc = 1.00
# Epoch 237 / 300: Loss = 0.094 Acc = 1.00
# Epoch 238 / 300: Loss = 0.093 Acc = 1.00
# Epoch 239 / 300: Loss = 0.092 Acc = 1.00
# Epoch 240 / 300: Loss = 0.091 Acc = 1.00
# Epoch 241 / 300: Loss = 0.090 Acc = 1.00
# Epoch 242 / 300: Loss = 0.089 Acc = 1.00
# Epoch 243 / 300: Loss = 0.088 Acc = 1.00
# Epoch 244 / 300: Loss = 0.087 Acc = 1.00
# Epoch 245 / 300: Loss = 0.086 Acc = 1.00
# Epoch 246 / 300: Loss = 0.085 Acc = 1.00
# Epoch 247 / 300: Loss = 0.084 Acc = 1.00
# Epoch 248 / 300: Loss = 0.083 Acc = 1.00
# Epoch 249 / 300: Loss = 0.082 Acc = 1.00
# Epoch 250 / 300: Loss = 0.081 Acc = 1.00
# Epoch 251 / 300: Loss = 0.080 Acc = 1.00
# Epoch 252 / 300: Loss = 0.080 Acc = 1.00
# Epoch 253 / 300: Loss = 0.079 Acc = 1.00
# Epoch 254 / 300: Loss = 0.078 Acc = 1.00
# Epoch 255 / 300: Loss = 0.077 Acc = 1.00
# Epoch 256 / 300: Loss = 0.076 Acc = 1.00
# Epoch 257 / 300: Loss = 0.076 Acc = 1.00
# Epoch 258 / 300: Loss = 0.075 Acc = 1.00
# Epoch 259 / 300: Loss = 0.074 Acc = 1.00
# Epoch 260 / 300: Loss = 0.073 Acc = 1.00
# Epoch 261 / 300: Loss = 0.073 Acc = 1.00
# Epoch 262 / 300: Loss = 0.072 Acc = 1.00
# Epoch 263 / 300: Loss = 0.071 Acc = 1.00
# Epoch 264 / 300: Loss = 0.070 Acc = 1.00
# Epoch 265 / 300: Loss = 0.070 Acc = 1.00
# Epoch 266 / 300: Loss = 0.069 Acc = 1.00
# Epoch 267 / 300: Loss = 0.068 Acc = 1.00
# Epoch 268 / 300: Loss = 0.068 Acc = 1.00
# Epoch 269 / 300: Loss = 0.067 Acc = 1.00
# Epoch 270 / 300: Loss = 0.066 Acc = 1.00
# Epoch 271 / 300: Loss = 0.066 Acc = 1.00
# Epoch 272 / 300: Loss = 0.065 Acc = 1.00
# Epoch 273 / 300: Loss = 0.064 Acc = 1.00
# Epoch 274 / 300: Loss = 0.064 Acc = 1.00
# Epoch 275 / 300: Loss = 0.063 Acc = 1.00
# Epoch 276 / 300: Loss = 0.063 Acc = 1.00
# Epoch 277 / 300: Loss = 0.062 Acc = 1.00
# Epoch 278 / 300: Loss = 0.062 Acc = 1.00
# Epoch 279 / 300: Loss = 0.061 Acc = 1.00
# Epoch 280 / 300: Loss = 0.060 Acc = 1.00
# Epoch 281 / 300: Loss = 0.060 Acc = 1.00
# Epoch 282 / 300: Loss = 0.059 Acc = 1.00
# Epoch 283 / 300: Loss = 0.059 Acc = 1.00
# Epoch 284 / 300: Loss = 0.058 Acc = 1.00
# Epoch 285 / 300: Loss = 0.058 Acc = 1.00
# Epoch 286 / 300: Loss = 0.057 Acc = 1.00
# Epoch 287 / 300: Loss = 0.057 Acc = 1.00
# Epoch 288 / 300: Loss = 0.056 Acc = 1.00
# Epoch 289 / 300: Loss = 0.056 Acc = 1.00
# Epoch 290 / 300: Loss = 0.055 Acc = 1.00
# Epoch 291 / 300: Loss = 0.055 Acc = 1.00
# Epoch 292 / 300: Loss = 0.054 Acc = 1.00
# Epoch 293 / 300: Loss = 0.054 Acc = 1.00
# Epoch 294 / 300: Loss = 0.053 Acc = 1.00
# Epoch 295 / 300: Loss = 0.053 Acc = 1.00
# Epoch 296 / 300: Loss = 0.052 Acc = 1.00
# Epoch 297 / 300: Loss = 0.052 Acc = 1.00
# Epoch 298 / 300: Loss = 0.052 Acc = 1.00
# Epoch 299 / 300: Loss = 0.051 Acc = 1.00
# Epoch 300 / 300: Loss = 0.051 Acc = 1.00

# %%
def print_result(model):
    with torch.no_grad():
        input_sentence = training_data[0][0]
        labels = training_data[0][1]
        inputs = prepare_sequence(input_sentence, word_to_ix)
        tag_scores = model(inputs)

        tag_ids = torch.argmax(tag_scores, dim=1).numpy()
        tag_labels = [ix_to_tag[k] for k in tag_ids]
        print(f"Sentence:  {input_sentence}")
        print(f"Labels:    {labels}")
        print(f"Predicted: {tag_labels}")

# %%
print_result(model_classical)
# Out:
# Sentence:  ['The', 'dog', 'ate', 'the', 'apple']
# Labels:    ['DET', 'NN', 'V', 'DET', 'NN']
# Predicted: ['DET', 'NN', 'V', 'DET', 'NN']

# %%
n_qubits = 4

model_quantum = LSTMTagger(embedding_dim, 
                        hidden_dim, 
                        vocab_size=len(word_to_ix), 
                        tagset_size=len(tag_to_ix), 
                        n_qubits=n_qubits)
# Out:
# Tagger will use Quantum LSTM
# weight_shapes = (n_qlayers, n_qubits) = (1, 4)

# %%
history_quantum = train(model_quantum, n_epochs)
# Out:
# Epoch 1 / 300: Loss = 1.209 Acc = 0.22
# Epoch 2 / 300: Loss = 1.189 Acc = 0.22
# Epoch 3 / 300: Loss = 1.171 Acc = 0.22
# Epoch 4 / 300: Loss = 1.155 Acc = 0.22
# Epoch 5 / 300: Loss = 1.141 Acc = 0.33
# Epoch 6 / 300: Loss = 1.129 Acc = 0.33
# Epoch 7 / 300: Loss = 1.118 Acc = 0.33
# Epoch 8 / 300: Loss = 1.108 Acc = 0.33
# Epoch 9 / 300: Loss = 1.100 Acc = 0.44
# Epoch 10 / 300: Loss = 1.092 Acc = 0.56
# Epoch 11 / 300: Loss = 1.085 Acc = 0.33
# Epoch 12 / 300: Loss = 1.079 Acc = 0.44
# Epoch 13 / 300: Loss = 1.073 Acc = 0.56
# Epoch 14 / 300: Loss = 1.068 Acc = 0.44
# Epoch 15 / 300: Loss = 1.064 Acc = 0.44
# Epoch 16 / 300: Loss = 1.059 Acc = 0.44
# Epoch 17 / 300: Loss = 1.055 Acc = 0.56
# Epoch 18 / 300: Loss = 1.052 Acc = 0.56
# Epoch 19 / 300: Loss = 1.048 Acc = 0.44
# Epoch 20 / 300: Loss = 1.045 Acc = 0.44
# Epoch 21 / 300: Loss = 1.042 Acc = 0.44
# Epoch 22 / 300: Loss = 1.039 Acc = 0.44
# Epoch 23 / 300: Loss = 1.035 Acc = 0.44
# Epoch 24 / 300: Loss = 1.032 Acc = 0.44
# Epoch 25 / 300: Loss = 1.029 Acc = 0.44
# Epoch 26 / 300: Loss = 1.026 Acc = 0.44
# Epoch 27 / 300: Loss = 1.023 Acc = 0.44
# Epoch 28 / 300: Loss = 1.020 Acc = 0.44
# Epoch 29 / 300: Loss = 1.017 Acc = 0.44
# Epoch 30 / 300: Loss = 1.013 Acc = 0.44
# Epoch 31 / 300: Loss = 1.010 Acc = 0.44
# Epoch 32 / 300: Loss = 1.006 Acc = 0.44
# Epoch 33 / 300: Loss = 1.002 Acc = 0.44
# Epoch 34 / 300: Loss = 0.998 Acc = 0.44
# Epoch 35 / 300: Loss = 0.994 Acc = 0.44
# Epoch 36 / 300: Loss = 0.990 Acc = 0.44
# Epoch 37 / 300: Loss = 0.985 Acc = 0.44
# Epoch 38 / 300: Loss = 0.981 Acc = 0.56
# Epoch 39 / 300: Loss = 0.976 Acc = 0.56
# Epoch 40 / 300: Loss = 0.971 Acc = 0.56
# Epoch 41 / 300: Loss = 0.965 Acc = 0.56
# Epoch 42 / 300: Loss = 0.960 Acc = 0.56
# Epoch 43 / 300: Loss = 0.954 Acc = 0.67
# Epoch 44 / 300: Loss = 0.948 Acc = 0.67
# Epoch 45 / 300: Loss = 0.942 Acc = 0.67
# Epoch 46 / 300: Loss = 0.936 Acc = 0.67
# Epoch 47 / 300: Loss = 0.929 Acc = 0.67
# Epoch 48 / 300: Loss = 0.922 Acc = 0.67
# Epoch 49 / 300: Loss = 0.915 Acc = 0.67
# Epoch 50 / 300: Loss = 0.908 Acc = 0.67
# Epoch 51 / 300: Loss = 0.900 Acc = 0.56
# Epoch 52 / 300: Loss = 0.892 Acc = 0.56
# Epoch 53 / 300: Loss = 0.884 Acc = 0.56
# Epoch 54 / 300: Loss = 0.876 Acc = 0.56
# Epoch 55 / 300: Loss = 0.867 Acc = 0.67
# Epoch 56 / 300: Loss = 0.858 Acc = 0.67
# Epoch 57 / 300: Loss = 0.850 Acc = 0.67
# Epoch 58 / 300: Loss = 0.841 Acc = 0.67
# Epoch 59 / 300: Loss = 0.832 Acc = 0.67
# Epoch 60 / 300: Loss = 0.824 Acc = 0.67
# Epoch 61 / 300: Loss = 0.815 Acc = 0.67
# Epoch 62 / 300: Loss = 0.807 Acc = 0.67
# Epoch 63 / 300: Loss = 0.798 Acc = 0.67
# Epoch 64 / 300: Loss = 0.790 Acc = 0.67
# Epoch 65 / 300: Loss = 0.782 Acc = 0.67
# Epoch 66 / 300: Loss = 0.773 Acc = 0.67
# Epoch 67 / 300: Loss = 0.765 Acc = 0.67
# Epoch 68 / 300: Loss = 0.757 Acc = 0.67
# Epoch 69 / 300: Loss = 0.749 Acc = 0.67
# Epoch 70 / 300: Loss = 0.740 Acc = 0.67
# Epoch 71 / 300: Loss = 0.732 Acc = 0.67
# Epoch 72 / 300: Loss = 0.724 Acc = 0.78
# Epoch 73 / 300: Loss = 0.715 Acc = 0.78
# Epoch 74 / 300: Loss = 0.707 Acc = 0.78
# Epoch 75 / 300: Loss = 0.699 Acc = 0.78
# Epoch 76 / 300: Loss = 0.690 Acc = 0.78
# Epoch 77 / 300: Loss = 0.682 Acc = 0.78
# Epoch 78 / 300: Loss = 0.674 Acc = 0.78
# Epoch 79 / 300: Loss = 0.665 Acc = 0.78
# Epoch 80 / 300: Loss = 0.657 Acc = 0.78
# Epoch 81 / 300: Loss = 0.649 Acc = 0.78
# Epoch 82 / 300: Loss = 0.641 Acc = 0.78
# Epoch 83 / 300: Loss = 0.632 Acc = 0.78
# Epoch 84 / 300: Loss = 0.624 Acc = 0.78
# Epoch 85 / 300: Loss = 0.616 Acc = 0.78
# Epoch 86 / 300: Loss = 0.608 Acc = 0.78
# Epoch 87 / 300: Loss = 0.600 Acc = 0.78
# Epoch 88 / 300: Loss = 0.592 Acc = 0.78
# Epoch 89 / 300: Loss = 0.584 Acc = 0.78
# Epoch 90 / 300: Loss = 0.577 Acc = 0.78
# Epoch 91 / 300: Loss = 0.569 Acc = 0.78
# Epoch 92 / 300: Loss = 0.561 Acc = 0.78
# Epoch 93 / 300: Loss = 0.553 Acc = 0.78
# Epoch 94 / 300: Loss = 0.545 Acc = 0.78
# Epoch 95 / 300: Loss = 0.538 Acc = 0.78
# Epoch 96 / 300: Loss = 0.530 Acc = 0.78
# Epoch 97 / 300: Loss = 0.522 Acc = 0.78
# Epoch 98 / 300: Loss = 0.514 Acc = 0.78
# Epoch 99 / 300: Loss = 0.507 Acc = 0.78
# Epoch 100 / 300: Loss = 0.499 Acc = 0.78
# Epoch 101 / 300: Loss = 0.491 Acc = 0.78
# Epoch 102 / 300: Loss = 0.483 Acc = 0.78
# Epoch 103 / 300: Loss = 0.475 Acc = 0.78
# Epoch 104 / 300: Loss = 0.467 Acc = 0.78
# Epoch 105 / 300: Loss = 0.459 Acc = 0.78
# Epoch 106 / 300: Loss = 0.451 Acc = 0.78
# Epoch 107 / 300: Loss = 0.443 Acc = 0.78
# Epoch 108 / 300: Loss = 0.435 Acc = 0.78
# Epoch 109 / 300: Loss = 0.427 Acc = 0.89
# Epoch 110 / 300: Loss = 0.419 Acc = 0.89
# Epoch 111 / 300: Loss = 0.411 Acc = 1.00
# Epoch 112 / 300: Loss = 0.402 Acc = 1.00
# Epoch 113 / 300: Loss = 0.394 Acc = 1.00
# Epoch 114 / 300: Loss = 0.386 Acc = 1.00
# Epoch 115 / 300: Loss = 0.378 Acc = 1.00
# Epoch 116 / 300: Loss = 0.370 Acc = 1.00
# Epoch 117 / 300: Loss = 0.362 Acc = 1.00
# Epoch 118 / 300: Loss = 0.354 Acc = 1.00
# Epoch 119 / 300: Loss = 0.346 Acc = 1.00
# Epoch 120 / 300: Loss = 0.338 Acc = 1.00
# Epoch 121 / 300: Loss = 0.331 Acc = 1.00
# Epoch 122 / 300: Loss = 0.323 Acc = 1.00
# Epoch 123 / 300: Loss = 0.315 Acc = 1.00
# Epoch 124 / 300: Loss = 0.308 Acc = 1.00
# Epoch 125 / 300: Loss = 0.301 Acc = 1.00
# Epoch 126 / 300: Loss = 0.294 Acc = 1.00
# Epoch 127 / 300: Loss = 0.287 Acc = 1.00
# Epoch 128 / 300: Loss = 0.280 Acc = 1.00
# Epoch 129 / 300: Loss = 0.273 Acc = 1.00
# Epoch 130 / 300: Loss = 0.266 Acc = 1.00
# Epoch 131 / 300: Loss = 0.260 Acc = 1.00
# Epoch 132 / 300: Loss = 0.254 Acc = 1.00
# Epoch 133 / 300: Loss = 0.247 Acc = 1.00
# Epoch 134 / 300: Loss = 0.241 Acc = 1.00
# Epoch 135 / 300: Loss = 0.236 Acc = 1.00
# Epoch 136 / 300: Loss = 0.230 Acc = 1.00
# Epoch 137 / 300: Loss = 0.224 Acc = 1.00
# Epoch 138 / 300: Loss = 0.219 Acc = 1.00
# Epoch 139 / 300: Loss = 0.214 Acc = 1.00
# Epoch 140 / 300: Loss = 0.209 Acc = 1.00
# Epoch 141 / 300: Loss = 0.204 Acc = 1.00
# Epoch 142 / 300: Loss = 0.199 Acc = 1.00
# Epoch 143 / 300: Loss = 0.195 Acc = 1.00
# Epoch 144 / 300: Loss = 0.190 Acc = 1.00
# Epoch 145 / 300: Loss = 0.186 Acc = 1.00
# Epoch 146 / 300: Loss = 0.182 Acc = 1.00
# Epoch 147 / 300: Loss = 0.177 Acc = 1.00
# Epoch 148 / 300: Loss = 0.174 Acc = 1.00
# Epoch 149 / 300: Loss = 0.170 Acc = 1.00
# Epoch 150 / 300: Loss = 0.166 Acc = 1.00
# Epoch 151 / 300: Loss = 0.162 Acc = 1.00
# Epoch 152 / 300: Loss = 0.159 Acc = 1.00
# Epoch 153 / 300: Loss = 0.156 Acc = 1.00
# Epoch 154 / 300: Loss = 0.152 Acc = 1.00
# Epoch 155 / 300: Loss = 0.149 Acc = 1.00
# Epoch 156 / 300: Loss = 0.146 Acc = 1.00
# Epoch 157 / 300: Loss = 0.143 Acc = 1.00
# Epoch 158 / 300: Loss = 0.140 Acc = 1.00
# Epoch 159 / 300: Loss = 0.137 Acc = 1.00
# Epoch 160 / 300: Loss = 0.135 Acc = 1.00
# Epoch 161 / 300: Loss = 0.132 Acc = 1.00
# Epoch 162 / 300: Loss = 0.130 Acc = 1.00
# Epoch 163 / 300: Loss = 0.127 Acc = 1.00
# Epoch 164 / 300: Loss = 0.125 Acc = 1.00
# Epoch 165 / 300: Loss = 0.122 Acc = 1.00
# Epoch 166 / 300: Loss = 0.120 Acc = 1.00
# Epoch 167 / 300: Loss = 0.118 Acc = 1.00
# Epoch 168 / 300: Loss = 0.116 Acc = 1.00
# Epoch 169 / 300: Loss = 0.114 Acc = 1.00
# Epoch 170 / 300: Loss = 0.112 Acc = 1.00
# Epoch 171 / 300: Loss = 0.110 Acc = 1.00
# Epoch 172 / 300: Loss = 0.108 Acc = 1.00
# Epoch 173 / 300: Loss = 0.106 Acc = 1.00
# Epoch 174 / 300: Loss = 0.104 Acc = 1.00
# Epoch 175 / 300: Loss = 0.102 Acc = 1.00
# Epoch 176 / 300: Loss = 0.101 Acc = 1.00
# Epoch 177 / 300: Loss = 0.099 Acc = 1.00
# Epoch 178 / 300: Loss = 0.098 Acc = 1.00
# Epoch 179 / 300: Loss = 0.096 Acc = 1.00
# Epoch 180 / 300: Loss = 0.094 Acc = 1.00
# Epoch 181 / 300: Loss = 0.093 Acc = 1.00
# Epoch 182 / 300: Loss = 0.092 Acc = 1.00
# Epoch 183 / 300: Loss = 0.090 Acc = 1.00
# Epoch 184 / 300: Loss = 0.089 Acc = 1.00
# Epoch 185 / 300: Loss = 0.087 Acc = 1.00
# Epoch 186 / 300: Loss = 0.086 Acc = 1.00
# Epoch 187 / 300: Loss = 0.085 Acc = 1.00
# Epoch 188 / 300: Loss = 0.084 Acc = 1.00
# Epoch 189 / 300: Loss = 0.082 Acc = 1.00
# Epoch 190 / 300: Loss = 0.081 Acc = 1.00
# Epoch 191 / 300: Loss = 0.080 Acc = 1.00
# Epoch 192 / 300: Loss = 0.079 Acc = 1.00
# Epoch 193 / 300: Loss = 0.078 Acc = 1.00
# Epoch 194 / 300: Loss = 0.077 Acc = 1.00
# Epoch 195 / 300: Loss = 0.076 Acc = 1.00
# Epoch 196 / 300: Loss = 0.075 Acc = 1.00
# Epoch 197 / 300: Loss = 0.074 Acc = 1.00
# Epoch 198 / 300: Loss = 0.073 Acc = 1.00
# Epoch 199 / 300: Loss = 0.072 Acc = 1.00
# Epoch 200 / 300: Loss = 0.071 Acc = 1.00
# Epoch 201 / 300: Loss = 0.070 Acc = 1.00
# Epoch 202 / 300: Loss = 0.069 Acc = 1.00
# Epoch 203 / 300: Loss = 0.068 Acc = 1.00
# Epoch 204 / 300: Loss = 0.067 Acc = 1.00
# Epoch 205 / 300: Loss = 0.067 Acc = 1.00
# Epoch 206 / 300: Loss = 0.066 Acc = 1.00
# Epoch 207 / 300: Loss = 0.065 Acc = 1.00
# Epoch 208 / 300: Loss = 0.064 Acc = 1.00
# Epoch 209 / 300: Loss = 0.064 Acc = 1.00
# Epoch 210 / 300: Loss = 0.063 Acc = 1.00
# Epoch 211 / 300: Loss = 0.062 Acc = 1.00
# Epoch 212 / 300: Loss = 0.061 Acc = 1.00
# Epoch 213 / 300: Loss = 0.061 Acc = 1.00
# Epoch 214 / 300: Loss = 0.060 Acc = 1.00
# Epoch 215 / 300: Loss = 0.059 Acc = 1.00
# Epoch 216 / 300: Loss = 0.059 Acc = 1.00
# Epoch 217 / 300: Loss = 0.058 Acc = 1.00
# Epoch 218 / 300: Loss = 0.057 Acc = 1.00
# Epoch 219 / 300: Loss = 0.057 Acc = 1.00
# Epoch 220 / 300: Loss = 0.056 Acc = 1.00
# Epoch 221 / 300: Loss = 0.055 Acc = 1.00
# Epoch 222 / 300: Loss = 0.055 Acc = 1.00
# Epoch 223 / 300: Loss = 0.054 Acc = 1.00
# Epoch 224 / 300: Loss = 0.054 Acc = 1.00
# Epoch 225 / 300: Loss = 0.053 Acc = 1.00
# Epoch 226 / 300: Loss = 0.053 Acc = 1.00
# Epoch 227 / 300: Loss = 0.052 Acc = 1.00
# Epoch 228 / 300: Loss = 0.052 Acc = 1.00
# Epoch 229 / 300: Loss = 0.051 Acc = 1.00
# Epoch 230 / 300: Loss = 0.051 Acc = 1.00
# Epoch 231 / 300: Loss = 0.050 Acc = 1.00
# Epoch 232 / 300: Loss = 0.050 Acc = 1.00
# Epoch 233 / 300: Loss = 0.049 Acc = 1.00
# Epoch 234 / 300: Loss = 0.049 Acc = 1.00
# Epoch 235 / 300: Loss = 0.048 Acc = 1.00
# Epoch 236 / 300: Loss = 0.048 Acc = 1.00
# Epoch 237 / 300: Loss = 0.047 Acc = 1.00
# Epoch 238 / 300: Loss = 0.047 Acc = 1.00
# Epoch 239 / 300: Loss = 0.046 Acc = 1.00
# Epoch 240 / 300: Loss = 0.046 Acc = 1.00
# Epoch 241 / 300: Loss = 0.046 Acc = 1.00
# Epoch 242 / 300: Loss = 0.045 Acc = 1.00
# Epoch 243 / 300: Loss = 0.045 Acc = 1.00
# Epoch 244 / 300: Loss = 0.044 Acc = 1.00
# Epoch 245 / 300: Loss = 0.044 Acc = 1.00
# Epoch 246 / 300: Loss = 0.044 Acc = 1.00
# Epoch 247 / 300: Loss = 0.043 Acc = 1.00
# Epoch 248 / 300: Loss = 0.043 Acc = 1.00
# Epoch 249 / 300: Loss = 0.042 Acc = 1.00
# Epoch 250 / 300: Loss = 0.042 Acc = 1.00
# Epoch 251 / 300: Loss = 0.042 Acc = 1.00
# Epoch 252 / 300: Loss = 0.041 Acc = 1.00
# Epoch 253 / 300: Loss = 0.041 Acc = 1.00
# Epoch 254 / 300: Loss = 0.041 Acc = 1.00
# Epoch 255 / 300: Loss = 0.040 Acc = 1.00
# Epoch 256 / 300: Loss = 0.040 Acc = 1.00
# Epoch 257 / 300: Loss = 0.040 Acc = 1.00
# Epoch 258 / 300: Loss = 0.039 Acc = 1.00
# Epoch 259 / 300: Loss = 0.039 Acc = 1.00
# Epoch 260 / 300: Loss = 0.039 Acc = 1.00
# Epoch 261 / 300: Loss = 0.038 Acc = 1.00
# Epoch 262 / 300: Loss = 0.038 Acc = 1.00
# Epoch 263 / 300: Loss = 0.038 Acc = 1.00
# Epoch 264 / 300: Loss = 0.038 Acc = 1.00
# Epoch 265 / 300: Loss = 0.037 Acc = 1.00
# Epoch 266 / 300: Loss = 0.037 Acc = 1.00
# Epoch 267 / 300: Loss = 0.037 Acc = 1.00
# Epoch 268 / 300: Loss = 0.036 Acc = 1.00
# Epoch 269 / 300: Loss = 0.036 Acc = 1.00
# Epoch 270 / 300: Loss = 0.036 Acc = 1.00
# Epoch 271 / 300: Loss = 0.036 Acc = 1.00
# Epoch 272 / 300: Loss = 0.035 Acc = 1.00
# Epoch 273 / 300: Loss = 0.035 Acc = 1.00
# Epoch 274 / 300: Loss = 0.035 Acc = 1.00
# Epoch 275 / 300: Loss = 0.035 Acc = 1.00
# Epoch 276 / 300: Loss = 0.034 Acc = 1.00
# Epoch 277 / 300: Loss = 0.034 Acc = 1.00
# Epoch 278 / 300: Loss = 0.034 Acc = 1.00
# Epoch 279 / 300: Loss = 0.034 Acc = 1.00
# Epoch 280 / 300: Loss = 0.033 Acc = 1.00
# Epoch 281 / 300: Loss = 0.033 Acc = 1.00
# Epoch 282 / 300: Loss = 0.033 Acc = 1.00
# Epoch 283 / 300: Loss = 0.033 Acc = 1.00
# Epoch 284 / 300: Loss = 0.033 Acc = 1.00
# Epoch 285 / 300: Loss = 0.032 Acc = 1.00
# Epoch 286 / 300: Loss = 0.032 Acc = 1.00
# Epoch 287 / 300: Loss = 0.032 Acc = 1.00
# Epoch 288 / 300: Loss = 0.032 Acc = 1.00
# Epoch 289 / 300: Loss = 0.031 Acc = 1.00
# Epoch 290 / 300: Loss = 0.031 Acc = 1.00
# Epoch 291 / 300: Loss = 0.031 Acc = 1.00
# Epoch 292 / 300: Loss = 0.031 Acc = 1.00
# Epoch 293 / 300: Loss = 0.031 Acc = 1.00
# Epoch 294 / 300: Loss = 0.030 Acc = 1.00
# Epoch 295 / 300: Loss = 0.030 Acc = 1.00
# Epoch 296 / 300: Loss = 0.030 Acc = 1.00
# Epoch 297 / 300: Loss = 0.030 Acc = 1.00
# Epoch 298 / 300: Loss = 0.030 Acc = 1.00
# Epoch 299 / 300: Loss = 0.029 Acc = 1.00
# Epoch 300 / 300: Loss = 0.029 Acc = 1.00

# %%
print_result(model_quantum)
# Out:
# Sentence:  ['The', 'dog', 'ate', 'the', 'apple']
# Labels:    ['DET', 'NN', 'V', 'DET', 'NN']
# Predicted: ['DET', 'NN', 'V', 'DET', 'NN']

# %% [markdown]
# ### Plot the training history

# %%
from matplotlib import pyplot as plt

def plot_history(history_classical, history_quantum):
    loss_c = history_classical['loss']
    acc_c = history_classical['acc']
    loss_q = history_quantum['loss']
    acc_q = history_quantum['acc']
    n_epochs = max([len(loss_c), len(loss_q)])
    x_epochs = [i for i in range(n_epochs)]
    
    fig, ax1 = plt.subplots()
    
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss")
    ax1.plot(loss_c, label="Classical LSTM loss", color='orange', linestyle='dashed')
    ax1.plot(loss_q, label="Quantum LSTM loss", color='red', linestyle='solid')

    ax2 = ax1.twinx()
    ax2.set_ylabel("Accuracy")
    ax2.plot(acc_c, label="Classical LSTM accuracy", color='steelblue', linestyle='dashed')
    ax2.plot(acc_q, label="Quantum LSTM accuracy", color='blue', linestyle='solid')

    plt.title("Part-of-Speech Tagger Training")
    plt.ylim(0., 1.1)
    #plt.legend(loc="upper right")
    fig.legend(loc="upper right", bbox_to_anchor=(1,0.8), bbox_transform=ax1.transAxes)

    plt.savefig("pos_training.pdf")
    plt.savefig("pos_training.png")
    plt.show()

# %%
plot_history(history_classical, history_quantum)

# %% [markdown]
# The loss function decreases as a function of the training epoch, and after 300 epochs both networks are able to tag correctly the first sentence. Due to the complexity of the simulation of the quantum circuit, it took approximatively 15 minutes to finish the training, to be compared to a mere 8 seconds for the classical case.
